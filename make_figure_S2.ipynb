# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import label, generate_binary_structure
from skimage.morphology import binary_opening
import napari
from matplotlib.animation import FuncAnimation

# %%
min_distances = np.load("min_distances.npy")
n_crystals = np.load("n_crystals.npy")

# %%
plt.scatter(min_distances, n_crystals)
plt.xlabel("Minimum distance to define a crystal (voxels)")
plt.ylabel("Number of crystallites")
plt.savefig("imgs/watershed_tuning.png", dpi=300)
